# %%
from hyperopt import mcmc_hyperopt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from hyperopt import mcmc_hyperopt
#
# File ~/Documents/Studie/2022:23/Thesis/mcmc/hyperopt.py:1
# ----> 1 from ray import tune
#       2 from ray.air import session
#       3 from ray import air, tune
#
# ModuleNotFoundError: No module named 'ray'

# %%
results = mcmc_hyperopt(dgpIndex=6)
# Out:
# Theoretical optimal mse for f, y, enc: 19.720
# 2023-05-13 12:19:29,583	INFO worker.py:1625 -- Started a local Ray instance.
# 2023-05-13 12:19:31,309	INFO tune.py:218 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `Tuner(...)`.
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023-05-13 12:19:47</td></tr>
# <tr><td>Running for: </td><td>00:00:15.30        </td></tr>
# <tr><td>Memory:      </td><td>5.7/8.0 GiB        </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 2.0/4 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
# ...
