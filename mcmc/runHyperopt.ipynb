# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../')

from hyperopt import mcmc_hyperopt
import mcmc
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
results = mcmc_hyperopt(dgpIndex=20, T_train=1000,T_val=0,useFolds=True,stepsize=50,folds=5)
# Out:
# (raylet) [2023-05-17 17:32:19,382 E 54170 1547791] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-05-17_15-31-08_608682_54105 is over 95% full, available space: 4850438144; capacity: 250685575168. Object creation will fail if spilling is required.
# Theoretical optimal mse for f, y, enc: 117.352
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023-05-17 17:33:05</td></tr>
# <tr><td>Running for: </td><td>00:00:44.93        </td></tr>
# <tr><td>Memory:      </td><td>6.3/8.0 GiB        </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 4.0/4 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
# ...

# %%
dir(results)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_annotated',
#  '_experiment_analysis',
#  '_local_path',
#  '_populate_exception',
#  '_remote_path',
#  '_results',
#  '_trial_to_result',
#  'errors',
#  'experiment_path',
#  'get_best_result',
#  'get_dataframe',
#  'num_errors',
#  'num_terminated']

# %%
results.get_dataframe().sort_values(by='score').to_csv('HyperOptResultsdgp20.2.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 results.get_dataframe().sort_values(by='score').to_csv('HyperOptResultsdgp20.2.csv')
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:6912, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6908 elif len(by):
#    6909     # len(by) == 1
#    6911     by = by[0]
# ...

# %%
results.get_dataframe()
# Out:
#    val_loss  time_this_iter_s   done  training_iteration     trial_id  \
# 0       NaN          0.013911  False                 156  03552_00000
# 1       NaN          0.012488  False                 156  03552_00001
# 2       NaN          0.057594  False                 156  03552_00002
# 3       NaN          0.018339  False                 156  03552_00003
# 4       NaN          0.052703  False                 156  03552_00004
# 5       NaN          0.166644  False                 156  03552_00005
# 6       NaN          0.031844  False                 156  03552_00006
# 7       NaN          0.039584  False                 156  03552_00007
# 8       NaN          0.025521  False                 156  03552_00008
# 9       NaN          0.035429  False                 156  03552_00009
#
#                   date   timestamp  time_total_s    pid     hostname  \
# 0  2023-05-17_17-33-20  1684337600     47.137695  55734  Julians-MBP
# ...

# %%
results.get_best_result('score', 'min')
# Out:
# Result(
#   metrics={'score': 0.02771528703160584, 'done': True, 'trial_id': '03552_00002', 'experiment_tag': '2_activation=Tanh,dropout=0.7000,hidden=4,n_iter=60.0000'},
#   path='/Users/julianvanmeggelen/ray_results/lambda_2023-05-17_17-32-20/lambda_03552_00002_2_activation=Tanh,dropout=0.7000,hidden=4,n_iter=60.0000_2023-05-17_17-32-44',
#   checkpoint=None
# )
# (raylet) [2023-05-17 20:40:37,871 E 54170 1547791] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-05-17_15-31-08_608682_54105 is over 95% full, available space: 3668414464; capacity: 250685575168. Object creation will fail if spilling is required.
# (raylet) [2023-05-17 20:40:47,927 E 54170 1547791] (raylet) file_system_monitor.cc:111: /tmp/ray/session_2023-05-17_15-31-08_608682_54105 is over 95% full, available space: 3690754048; capacity: 250685575168. Object creation will fail if spilling is required.
# ...

# %%
results
# Out:
# ResultGrid<[
#   Result(
#     metrics={'score': 0.040902565512806174, 'done': True, 'trial_id': '51f60_00000', 'experiment_tag': '0_activation=Identity,dropout=0.5000,hidden=2,lr=0.0001'},
#     path='/Users/julianvanmeggelen/ray_results/lambda_2023-05-17_15-32-50/lambda_51f60_00000_0_activation=Identity,dropout=0.5000,hidden=2,lr=0.0001_2023-05-17_15-32-53',
#     checkpoint=None
#   ),
#   Result(
#     metrics={'score': 0.04860392678529024, 'done': True, 'trial_id': '51f60_00001', 'experiment_tag': '1_activation=Tanh,dropout=0.2000,hidden=2,lr=0.0001'},
#     path='/Users/julianvanmeggelen/ray_results/lambda_2023-05-17_15-32-50/lambda_51f60_00001_1_activation=Tanh,dropout=0.2000,hidden=2,lr=0.0001_2023-05-17_15-33-03',
#     checkpoint=None
#   ),
#   Result(
#     metrics={'score': 0.06057382756844163, 'done': True, 'trial_id': '51f60_00002', 'experiment_tag': '2_activation=Sigmoid,dropout=0.7000,hidden=2,lr=0.0001'},
# ...
